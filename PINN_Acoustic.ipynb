# %% [markdown]
# <a href="https://colab.research.google.com/github/EliasLA79/PINN_Acoustic/blob/main/PINN_Acoustic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Primeros pasos para la realización de la PINN**
#
# *   Conectar a Github

# %%
# ============================================================
# INICIO — CONECTAR COLAB CON GITHUB
# ============================================================

import os
from google.colab import drive

# Montar Google Drive
drive.mount("/content/drive")

# Preparar SSH
os.makedirs("/root/.ssh", exist_ok=True)

# !cp /content/drive/MyDrive/Colab_SSH/id_ed25519 ~/.ssh/id_ed25519
# !cp /content/drive/MyDrive/Colab_SSH/id_ed25519.pub ~/.ssh/id_ed25519.pub

# !chmod 600 ~/.ssh/id_ed25519
# !chmod 644 ~/.ssh/id_ed25519.pub

# Registrar GitHub
# !ssh-keyscan -H github.com >> ~/.ssh/known_hosts 2>/dev/null

# Configurar identidad de Git
# !git config --global user.name "EliasLA79"
# !git config --global user.email "elias.leon7911@gmail.com"

# Entrar al repositorio
os.chdir("/content/PINN_Acoustic")

# Actualizar desde GitHub
# !git pull origin main

# Mostrar estado
# !git status
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# From github.com:EliasLA79/PINN_Acoustic
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
print("PINN Acoustic - GitHub conectado correctamente")
# Out:
# PINN Acoustic - GitHub conectado correctamente

# %%
# ============================================================
# GUARDAR CAMBIOS EN GITHUB
# ============================================================

# !git add .
#Descripción de cambios
# !git commit -m "Actualización del proyecto"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
